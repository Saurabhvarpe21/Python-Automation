# %%
import os
import pandas as pd
from openpyxl import load_workbook
f=pd.DataFrame(columns=['commodity_name','Not_Start "S" And 13 Char','G06 Folder is Empty'])

def validate_source_folder(folderName):
    if(folderName.startswith("S")):
        if(len(folderName)==13):
            return "valid"
        else:
            return "Folder name not 13 characters"
    else:
        return "Folder name not starting with S."

def massage_directory_path(rawpath):
    print(rawpath)
    return rawpath.replace('\\', '\\\\')
        
def Na_file():
    t=1
    print("Please enter the below details")
    source_folder = massage_directory_path(input("Enter the source directory: "));
    # get all the first level folders
    allFilesAndFolders =os.listdir(source_folder)
    
    for i in allFilesAndFolders:
        fullPath = source_folder + "\\" + i;
#         #Access first level folder
        if os.path.isdir(fullPath):
            #Source folder validation for S and 13 charecters
            validationOutput = validate_source_folder(i)
            if(validationOutput == "valid"):
                g06fullPath = fullPath + "\\" + "G06 TABLES"
#                 Check for G06 TABLES
                if os.path.isdir(g06fullPath):
                    allG06FilesAndFolders =os.listdir(g06fullPath)
#                     print(allG06FilesAndFolders)
                    if allG06FilesAndFolders:
                        for j in allG06FilesAndFolders:
                            fp = g06fullPath + "\\" 
                            currentObj = fp + j;
                            if(os.path.isfile(currentObj)):
    #                             #Form new file name
                                oldFileFullPath = fp+j;
                                print("oldFileFullPath: ",oldFileFullPath );
                                if(j.endswith(".xlsx")) and (j.startswith("S")):
                                    df=pd.read_excel(oldFileFullPath)
                                    wb = load_workbook(oldFileFullPath)
                                    ws = wb._sheets[0]
                                    cl = df.columns
                                    le = df.shape[0]
                                    for r in range (0,le):
                                        if str(df[cl[8]][r]) == 'nan' and str(df[cl[9]][r]) == 'WIRE' and str(df[cl[11]][r])!= 'nan':
                                            ws[f'I{r+2}'].value = 'CUSTOM IMAGE'
                                        else:
                                            pass
                                    wb.save(oldFileFullPath)

                                else:
                                    os.remove(oldFileFullPath)                        
                        else:
                        print("empty g06 folder")
                        f.loc[t,'commodity_name']=i
                        f.loc[t,'G06 Folder is Empty']="✓"
                        t+=1
                else:
                    f.loc[t,'commodity_name']=i
                    f.loc[t,'G06 TABLES folder not found']="✓"
                    t+=1
                    print(i + " : " + validationOutput)
            else:
                f.loc[t,'commodity_name']=i
                f.loc[t,'Not_Start "S" And 13 Char']="✓"
                t+=1

        f.to_excel('test.xlsx',index=False)
# Out:
# Please enter the below details
# Enter the source directory: C:\Users\Saurabh\Desktop\Automation\SAMPLES
# C:\Users\Saurabh\Desktop\Automation\SAMPLES
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12183-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12275-011.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12275-021.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12275-031.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12275-041.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12275-051.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12655-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12987-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12991-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-12991-001.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-13144-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-13144-001.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-084\G06 TABLES\S70-00030-084_G06_A66-14353-000.xlsx
# S70-00030-154 : valid
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12183-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12275-021.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12275-031.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12275-041.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12655-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12987-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-001.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-002.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-003.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-004.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-12991-005.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-13144-001.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-252\G06 TABLES\S70-00030-252_G06_A66-14353-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12183-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-011.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-021.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-031.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-041.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-051.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-061.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-071.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-081.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-091.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12275-101.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12655-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12671-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-12987-000.xlsx
# oldFileFullPath:  C:\\Users\\Saurabh\\Desktop\\Automation\\SAMPLES\S70-00030-279\G06 TABLES\S70-00030-279_G06_A66-13144-001.xlsx
# empty g06 folder
# S70-00030-587 : valid
# S70-00030-619 : valid
# empty g06 folder
